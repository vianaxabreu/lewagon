# %% [markdown]
# # Multiple files with `pandas`

# %%
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# ## Merge Practice

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %% [markdown]
# ### Inner Merge Practice

# %%
inner_merged_df = a_df.merge(b_df, on='Country')
inner_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('inner_merge',
    inner_merged_shape=inner_merged_df.shape,
    inner_merged_nulls=sum(inner_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/code/cjw21889/le-wagon/lw-data-solutions/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 2 items
#
# tests/test_inner_merge.py::TestInnerMerge::test_inner_merged_nulls PASSED [ 50%]
# tests/test_inner_merge.py::TestInnerMerge::test_inner_merged_shape PASSED [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/inner_merge.pickle
#
# git commit -m 'Completed inner_merge step'
#
# git push origin master

# %% [markdown]
# ### Left Merge Practice

# %%
left_merged_df = a_df.merge(b_df, on='Country', how='left')
left_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('left_merge',
    left_merged_shape=left_merged_df.shape,
    left_merged_nulls=sum(left_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/code/cjw21889/le-wagon/lw-data-solutions/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 2 items
#
# tests/test_left_merge.py::TestLeftMerge::test_left_merged_df_shape PASSED [ 50%]
# tests/test_left_merge.py::TestLeftMerge::test_left_merged_nulls PASSED   [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/left_merge.pickle
#
# git commit -m 'Completed left_merge step'
#
# git push origin master

# %% [markdown]
# ### Right Merge Practice

# %%
right_merged_df = a_df.merge(b_df, on='Country', how='right')
right_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('right_merge',
    right_merged_shape=right_merged_df.shape,
    right_merged_nulls=sum(right_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/code/cjw21889/le-wagon/lw-data-solutions/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 2 items
#
# tests/test_right_merge.py::TestRightMerge::test_right_merged_df_shape PASSED [ 50%]
# tests/test_right_merge.py::TestRightMerge::test_right_merged_nulls PASSED [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/right_merge.pickle
#
# git commit -m 'Completed right_merge step'
#
# git push origin master

# %% [markdown]
# ### Outer Merge Practice

# %%
outer_merged_df = a_df.merge(b_df, on='Country', how='outer')
outer_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN
# 4   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('outer_merge',
    outer_merged_shape=outer_merged_df.shape,
    outer_merged_nulls=sum(outer_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/code/cjw21889/le-wagon/lw-data-solutions/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 2 items
#
# tests/test_outer_merge.py::TestOuterMerge::test_outer_merged_df_shape PASSED [ 50%]
# tests/test_outer_merge.py::TestOuterMerge::test_outer_merged_nulls PASSED [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/outer_merge.pickle
#
# git commit -m 'Completed outer_merge step'
#
# git push origin master

# %% [markdown]
# ## Join Practice

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df)
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %% [markdown]
# ## Concat Practice

# %%
concat_df = pd.concat([a_df, b_df], axis="index", sort=False)
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 0  Germany             NaN       NaN  0.936
# 1   France             NaN       NaN  0.901
# 2  Belgium             NaN       NaN  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# ## Olympic Sports and Medals, 1896-2014

# %%
countries_df = pd.read_csv('../data/archive/dictionary.csv')
countries_df.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
summer_df = pd.read_csv('../data/archive/summer.csv')
summer_df.rename(columns={"Country": "Code"}, inplace=True)
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
winter_df = pd.read_csv('../data/archive/winter.csv')
winter_df.rename(columns={"Country": "Code"}, inplace=True)
winter_df.head()
# Out:
#    Year      City     Sport Discipline               Athlete Code Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.  FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.  FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice  FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André  FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf  SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %% [markdown]
# ### Combining The Data

# %%
summer_countries_df = summer_df.merge(countries_df, on="Code")
summer_countries_df["Season"] = "Summer"
summer_countries_df.head()
# Out:
#    Year    City      Sport Discipline           Athlete Code Gender  \
# 0  1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 2  1896  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men
# 3  1896  Athens  Athletics  Athletics      DANI, Nandor  HUN    Men
# 4  1896  Athens  Athletics  Athletics    KELLNER, Gyula  HUN    Men
#
#              Event   Medal  Country  Population  GDP per Capita  Season
# 0   100M Freestyle    Gold  Hungary   9844686.0     12363.54346  Summer
# 1  1200M Freestyle    Gold  Hungary   9844686.0     12363.54346  Summer
# 2             100M  Bronze  Hungary   9844686.0     12363.54346  Summer
# 3             800M  Silver  Hungary   9844686.0     12363.54346  Summer
# 4         Marathon  Bronze  Hungary   9844686.0     12363.54346  Summer

# %%
winter_countries_df = winter_df.merge(countries_df, on="Code")
winter_countries_df["Season"] = "Winter"
winter_countries_df.head()
# Out:
#    Year      City     Sport Discipline              Athlete Code Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon          BERTHET, G.  FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon       MANDRILLON, C.  FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon  MANDRILLON, Maurice  FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon      VANDELLE, André  FRA    Men
# 4  1924  Chamonix   Curling    Curling          ALDEERT, H.  FRA    Men
#
#              Event   Medal Country  Population  GDP per Capita  Season
# 0  Military Patrol  Bronze  France  66808385.0    36205.568102  Winter
# 1  Military Patrol  Bronze  France  66808385.0    36205.568102  Winter
# 2  Military Patrol  Bronze  France  66808385.0    36205.568102  Winter
# 3  Military Patrol  Bronze  France  66808385.0    36205.568102  Winter
# 4          Curling  Bronze  France  66808385.0    36205.568102  Winter

# %%
all_df = pd.concat([summer_countries_df, winter_countries_df], sort=False)
all_df.head()
# Out:
#    Year    City      Sport Discipline           Athlete Code Gender  \
# 0  1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 2  1896  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men
# 3  1896  Athens  Athletics  Athletics      DANI, Nandor  HUN    Men
# 4  1896  Athens  Athletics  Athletics    KELLNER, Gyula  HUN    Men
#
#              Event   Medal  Country  Population  GDP per Capita  Season
# 0   100M Freestyle    Gold  Hungary   9844686.0     12363.54346  Summer
# 1  1200M Freestyle    Gold  Hungary   9844686.0     12363.54346  Summer
# 2             100M  Bronze  Hungary   9844686.0     12363.54346  Summer
# 3             800M  Silver  Hungary   9844686.0     12363.54346  Summer
# 4         Marathon  Bronze  Hungary   9844686.0     12363.54346  Summer

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('all_df',
    all_df_shape=all_df.shape,
    all_df_columns=set(all_df.columns)
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/code/cjw21889/le-wagon/lw-data-solutions/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 2 items
#
# tests/test_all_df.py::TestAllDf::test_all_df_columns PASSED              [ 50%]
# tests/test_all_df.py::TestAllDf::test_all_df_shape PASSED                [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/all_df.pickle
#
# git commit -m 'Completed all_df step'
#
# git push origin master

# %% [markdown]
# ### Top Countries Analysis

# %%
all_count_df = all_df[all_df["Year"] >= 1984] \
    .groupby(["Country"]) \
    .count()[["Medal"]] \
    .sort_values(by="Medal", ascending=False) \
    .rename(columns={'Medal':'Medal Count'})
top_10_df = all_count_df.head(10)

# %%
top_10_df.plot(kind="bar");

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games',
    top_country_1=top_10_df.iloc[0]['Medal Count'],
    top_country_10=top_10_df.iloc[9]['Medal Count'],
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/code/cjw21889/le-wagon/lw-data-solutions/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 1 item
#
# tests/test_olympic_games.py::TestOlympicGames::test_top_10_countries_medals PASSED [100%]
#
# ============================== 1 passed in 0.12s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games.pickle
#
# git commit -m 'Completed olympic_games step'
#
# git push origin master

# %%
season_count_df = all_df[all_df["Year"] >= 1984].groupby(["Country", "Season"])["Medal"].count().unstack()
season_count_df.fillna(0, inplace=True)
season_count_df["Summer"] = season_count_df["Summer"].astype(int)
season_count_df["Winter"] = season_count_df["Winter"].astype(int)
season_count_df['Total'] = season_count_df.sum(axis=1)
top_10_season_df = season_count_df.sort_values(by='Total', ascending=False).head(10) '

# %%
season_count_df = all_df[all_df["Year"] >= 1984].groupby(["Country", "Season"])["Medal"].count().unstack()

# %%
season_count_df
# Out:
# Season           Summer  Winter
# Country
# Afghanistan         2.0     NaN
# Algeria            15.0     NaN
# Argentina         173.0     NaN
# Armenia            11.0     NaN
# Australia         876.0    15.0
# ...                 ...     ...
# Venezuela           7.0     NaN
# Vietnam             2.0     NaN
# Virgin Islands*     1.0     NaN
# Zambia              2.0     NaN
# Zimbabwe            7.0     NaN
#
# [123 rows x 2 columns]

# %%
top_10_season_df[['Summer', 'Winter']].plot(kind="bar");

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games_season',
    top_country_season_shape=top_10_season_df.shape,
    top_country_1_summer=top_10_season_df.iloc[0]['Summer'],
    top_country_10_winter=top_10_season_df.iloc[9]['Winter'],
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/code/cjw21889/le-wagon/lw-data-solutions/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 3 items
#
# tests/test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_shape PASSED [ 33%]
# tests/test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_summer PASSED [ 66%]
# tests/test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_winter PASSED [100%]
#
# ============================== 3 passed in 0.07s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_season.pickle
#
# git commit -m 'Completed olympic_games_season step'
#
# git push origin master

# %%
all_df[(all_df.Year==2008) & (all_df.Event=='Basketball') & (all_df.Medal=='Gold')]
# Out:
#       Year     City       Sport  Discipline                Athlete Code  \
# 5540  2008  Beijing  Basketball  Basketball       ANTHONY, Carmelo  USA
# 5541  2008  Beijing  Basketball  Basketball         BOOZER, Carlos  USA
# 5542  2008  Beijing  Basketball  Basketball            BOSH, Chris  USA
# 5543  2008  Beijing  Basketball  Basketball           BRYANT, Kobe  USA
# 5544  2008  Beijing  Basketball  Basketball         HOWARD, Dwight  USA
# 5545  2008  Beijing  Basketball  Basketball          JAMES, Lebron  USA
# 5546  2008  Beijing  Basketball  Basketball            KIDD, Jason  USA
# 5547  2008  Beijing  Basketball  Basketball            PAUL, Chris  USA
# 5548  2008  Beijing  Basketball  Basketball       PRINCE, Tayshaun  USA
# 5549  2008  Beijing  Basketball  Basketball          REDD, Michael  USA
# 5550  2008  Beijing  Basketball  Basketball           WADE, Dwyane  USA
# 5551  2008  Beijing  Basketball  Basketball        WILLIAMS, Deron  USA
# 5552  2008  Beijing  Basketball  Basketball      AUGUSTUS, Seimone  USA
# 5553  2008  Beijing  Basketball  Basketball              BIRD, Sue  USA
# 5554  2008  Beijing  Basketball  Basketball      CATCHINGS, Tamika  USA
# 5555  2008  Beijing  Basketball  Basketball         FOWLES, Sylvia  USA
# 5556  2008  Beijing  Basketball  Basketball           LAWSON, Kara  USA
# 5557  2008  Beijing  Basketball  Basketball           LESLIE, Lisa  USA
# 5558  2008  Beijing  Basketball  Basketball  MILTON-JONES, Delisha  USA
# 5559  2008  Beijing  Basketball  Basketball        PARKER, Candace  USA
# 5560  2008  Beijing  Basketball  Basketball      PONDEXTER, Cappie  USA
# 5561  2008  Beijing  Basketball  Basketball           SMITH, Katie  USA
# 5562  2008  Beijing  Basketball  Basketball         TAURASI, Diana  USA
# 5563  2008  Beijing  Basketball  Basketball         THOMPSON, Tina  USA
#
#      Gender       Event Medal        Country   Population  GDP per Capita  \
# 5540    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5541    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5542    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5543    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5544    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5545    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5546    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5547    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5548    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5549    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5550    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5551    Men  Basketball  Gold  United States  321418820.0    56115.718426
# 5552  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5553  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5554  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5555  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5556  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5557  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5558  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5559  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5560  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5561  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5562  Women  Basketball  Gold  United States  321418820.0    56115.718426
# 5563  Women  Basketball  Gold  United States  321418820.0    56115.718426
#
#       Season
# 5540  Summer
# 5541  Summer
# 5542  Summer
# 5543  Summer
# 5544  Summer
# 5545  Summer
# 5546  Summer
# 5547  Summer
# 5548  Summer
# 5549  Summer
# 5550  Summer
# 5551  Summer
# 5552  Summer
# 5553  Summer
# 5554  Summer
# 5555  Summer
# 5556  Summer
# 5557  Summer
# 5558  Summer
# 5559  Summer
# 5560  Summer
# 5561  Summer
# 5562  Summer
# 5563  Summer

# %%
# If we drop the athlete column we can check how many rows are duplicated - indicating a medal for a team sport
all_events_df = all_df.drop(columns='Athlete')
print('Total medal rows: ', all_events_df.shape[0])
print('multiple event winners: ', all_events_df.duplicated().sum())
# Out:
# Total medal rows:  30568
# multiple event winners:  15755

# %%
# We can drop duplicated rows to keep just one winner per event
all_events_df.drop_duplicates(inplace=True)
all_events_df.shape
# Out:
# (14813, 12)

# %%
all_events_df = all_events_df[all_events_df["Year"] >= 1984] \
    .groupby(["Country"]) \
    .count()[["Medal"]] \
    .sort_values(by="Medal", ascending=False) \
    .rename(columns={'Medal':'Event Count'})
top_10_events_df = all_events_df.head(10)

# %%
top_10_events_df.plot(kind='bar');

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games_event',
    top_country_event_shape=top_10_events_df.shape,
    top_country_1_event=top_10_events_df.iloc[0]['Event Count'],
    top_country_10_event=top_10_events_df.iloc[9]['Event Count'],
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/code/cjw21889/le-wagon/lw-data-solutions/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 3 items
#
# tests/test_olympic_games_event.py::TestOlympicGamesEvent::test_top_10_events_shape PASSED [ 33%]
# tests/test_olympic_games_event.py::TestOlympicGamesEvent::test_top_events_1 PASSED [ 66%]
# tests/test_olympic_games_event.py::TestOlympicGamesEvent::test_top_events_10 PASSED [100%]
#
# ============================== 3 passed in 0.07s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_event.pickle
#
# git commit -m 'Completed olympic_games_event step'
#
# git push origin master

# %%
top_10_combined = top_10_events_df.join(top_10_df, how='outer') \
    .sort_values(by='Medal Count', ascending=False)

top_10_combined.plot(kind='bar');

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games_combined',
    top_combined_shape=top_10_combined.shape,
    top_combined_1_event=top_10_combined.iloc[0]['Event Count'],
    top_combined_1_medal=top_10_combined.iloc[0]['Medal Count'],
    top_combined_10_event=top_10_combined.iloc[9]['Event Count'],
    top_combined_10_medal=top_10_combined.iloc[9]['Medal Count']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/chriswesterman/.pyenv/versions/lw3.8.12/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/chriswesterman/Desktop/02-Data-Toolkit/01-Data-Analysis/03-Multiple-Files-With-Pandas
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 3 items
#
# tests/test_olympic_games_combined.py::TestOlympicGamesCombined::test_combined_1 PASSED [ 33%]
# tests/test_olympic_games_combined.py::TestOlympicGamesCombined::test_combined_10 PASSED [ 66%]
# tests/test_olympic_games_combined.py::TestOlympicGamesCombined::test_top_10_combined_shape PASSED [100%]
#
# ============================== 3 passed in 0.10s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_combined.pickle
#
# git commit -m 'Completed olympic_games_combined step'
#
# git push origin master
